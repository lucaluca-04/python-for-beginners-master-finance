# %% [markdown]
# ## This is the first python program for beginner !!

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
A=10
B="Data Science!"

print(A,B)

x, y, z = 10, 20, 30

print(x)
print(y)
print(z)
# Out:
# 10 Data Science!
# 10
# 20
# 30
